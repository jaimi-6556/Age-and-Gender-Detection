# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.preprocessing.image import load_img
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
from PIL import Image
from tensorflow.keras.utils import plot_model # type: ignore
from pathlib import Path
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.keras.layers import Dropout, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
import warnings
warnings.filterwarnings("ignore", message=".*CuDNN.*")
warnings.filterwarnings("ignore", message=".*cuFFT.*")
warnings.filterwarnings("ignore", message=".*cuBLAS.*")
import os
# from tensorflow.keras.utils import np_utils
from tensorflow.keras import utils
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import datasets, layers, models
from PIL import Image

# %%
#BASE_DIRS = [r'//kaggle//input//utkface-new//UTKFace']
BASE_DIRS = [r'E:\E Drive\UTKFace']

# %%
image_paths = []
age_labels = []
gender_paths = []

for BASE_DIR in BASE_DIRS:
    for filename in tqdm(os.listdir(BASE_DIR)):
        temp = filename.split('_')
        if temp[0].isdigit():  # Check if the first part of the filename is a number
            age = int(temp[0])
            gender = int(temp[1])
            image_path = os.path.join(BASE_DIR, filename)
            image_paths.append(image_path)
            age_labels.append(age)
            gender_paths.append(gender)
# Out:
# 100%|██████████| 23708/23708 [00:00<00:00, 188278.54it/s]

# %%
df =pd.DataFrame()
df['image'], df['age'], df['gender'] = image_paths,age_labels,gender_paths
df.head()
# print(df.head())
print(f"Dataframe: {df}")
gender_dict = {0:'Male', 1:'Female'}
# Out:
# Dataframe:                                                    image  age  gender
# 0      E:\E Drive\UTKFace\100_0_0_20170112213500903.j...  100       0
# 1      E:\E Drive\UTKFace\100_0_0_20170112215240346.j...  100       0
# 2      E:\E Drive\UTKFace\100_1_0_20170110183726390.j...  100       1
# 3      E:\E Drive\UTKFace\100_1_0_20170112213001988.j...  100       1
# 4      E:\E Drive\UTKFace\100_1_0_20170112213303693.j...  100       1
# ...                                                  ...  ...     ...
# 23703  E:\E Drive\UTKFace\9_1_3_20161220222856346.jpg...    9       1
# 23704  E:\E Drive\UTKFace\9_1_3_20170104222949455.jpg...    9       1
# 23705  E:\E Drive\UTKFace\9_1_4_20170103200637399.jpg...    9       1
# 23706  E:\E Drive\UTKFace\9_1_4_20170103200814791.jpg...    9       1
# 23707  E:\E Drive\UTKFace\9_1_4_20170103213057382.jpg...    9       1
#
# [23708 rows x 3 columns]

# %%
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_paths, age_labels, gender_paths

# Debug print to check if the dataframe is populated correctly
print(f"Dataframe shape: {df.shape}")
print(f"First few rows of the dataframe: {df.head()}")

if not df.empty:
    gender_dict = {0: 'Male', 1: 'Female'}

    try:
        img = Image.open(df['image'][0])
        plt.axis('off')
        plt.imshow(img)
        plt.show()
    except Exception as e:
        print(f"Error opening image: {e}")
else:
    print("Dataframe is empty. No images found.")
# Out:
# Dataframe shape: (23708, 3)
# First few rows of the dataframe:                                                image  age  gender
# 0  E:\E Drive\UTKFace\100_0_0_20170112213500903.j...  100       0
# 1  E:\E Drive\UTKFace\100_0_0_20170112215240346.j...  100       0
# 2  E:\E Drive\UTKFace\100_1_0_20170110183726390.j...  100       1
# 3  E:\E Drive\UTKFace\100_1_0_20170112213001988.j...  100       1
# 4  E:\E Drive\UTKFace\100_1_0_20170112213303693.j...  100       1

# %%
sns.displot(df['age'],kde=True, bins=30)
plt.title('Age Distribution')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(25,25))
files = df.iloc[0:25]

# %%
def extract_feature(images):
    features = []
    for image in tqdm(images):
        # Load image and convert to grayscale
        img = Image.open(image).convert('L')
        # Resize image
        img = img.resize((128, 128), Image.BILINEAR)  # Use Image.ANTIALIAS

        img = np.array(img)
        features.append(img)
    
    features = np.array(features)

    features = features.reshape(len(features), 128, 128, 1)
    return features

# %%
X = extract_feature(df['image'])

print(f"X_shape: \t{X.shape}")
X = X / 255.0 #normalize the  image

y_gender = np.array(df['gender'])
y_age = np.array(df['age'])
print("Shape of y_gender:", y_gender.shape)
print("Shape of y_age:", y_age.shape)
# Out:
# 100%|██████████| 23708/23708 [00:24<00:00, 976.84it/s]
# X_shape: 	(23708, 128, 128, 1)
# Shape of y_gender: (23708,)
# Shape of y_age: (23708,)

# %%
input_shape = (128,128,1)

inputs = Input(input_shape) 

#convolution layers
conv1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
maxp1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(maxp1)
maxp2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(maxp2)
maxp3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(maxp3)
maxp4 = MaxPooling2D(pool_size=(2, 2))(conv4)

flatten = Flatten()(maxp4)

# Fully connected layers
dense1 = Dense(256, activation='relu')(flatten)
dense2 = Dense(256, activation='relu')(flatten)

dropout1 = Dropout(0.3)(dense1)
dropout2 = Dropout(0.3)(dense2)

# Output layers
output1 = Dense(1, activation='sigmoid', name='gender_out')(dropout1)
output2 = Dense(1, activation='relu', name='age_out')(dropout2)

model = Model(inputs=inputs, outputs=[output1, output2])


model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 126, 126,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 63, 63,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 61, 61,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 30, 30,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 14, 14,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 12, 12,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 6, 256) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 9216)      │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │  2,359,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │  2,359,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_out (Dense)  │ (None, 1)         │        257 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_out (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,107,458 (19.48 MB)
#  Trainable params: 5,107,458 (19.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Concatenate y_gender and y_age into a single array
y_combined = np.column_stack((y_gender, y_age))

# Split the dataset into training and temporary sets
X_train, X_temp, y_combined_train, y_combined_temp = train_test_split(X, y_combined, test_size=0.2, random_state=42)

# Từ phần còn lại, chia thành 50% testing và 50% validation
X_test, X_val, y_combined_test, y_combined_val = train_test_split(X_temp, y_combined_temp, test_size=0.5, random_state=42)

# Split y_combined back into y_gender and y_age
y_train_gender, y_train_age = y_combined_train[:, 0], y_combined_train[:, 1]
y_test_gender, y_test_age = y_combined_test[:, 0], y_combined_test[:, 1]
y_val_gender, y_val_age = y_combined_val[:, 0], y_combined_val[:, 1]

# %%
from keras.callbacks import LearningRateScheduler

model_path = './best_model.keras'

checkpointer = ModelCheckpoint(
    filepath=model_path,
    monitor='val_gender_out_accuracy',
    verbose=1,
    mode='max',
    save_best_only=True
)

model.compile(loss=['binary_crossentropy', 'mae'], 
              optimizer='adam', 
              metrics=['accuracy', 'mae'])

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.9 ** x)

# %%
total_images = len(image_paths)
print(f"Total number of images: {total_images}")

# Compute number of images in each set
train_images = len(X_train)
validation_images = len(X_val)
test_images = len(X_test)

print(f"Number of training images: {train_images}")
print(f"Number of validation images: {validation_images}")
print(f"Number of test images: {test_images}")
# Out:
# Total number of images: 23708
# Number of training images: 18966
# Number of validation images: 2371
# Number of test images: 2371

# %%
import tensorflow as tf

tf.config.run_functions_eagerly(True)

# Training model
history = model.fit(x=X_train, y=[y_train_gender, y_train_age], batch_size=128, epochs=100, validation_data=(X_val, [y_val_gender, y_val_age]),callbacks = [annealer, checkpointer])
# Out:
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 18.6131 - age_out_mae: 18.6131 - gender_out_accuracy: 0.5336 - gender_out_loss: 0.7892 - loss: 19.4023
# Epoch 1: val_gender_out_accuracy improved from -inf to 0.56137, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - age_out_loss: 18.5999 - age_out_mae: 18.5999 - gender_out_accuracy: 0.5337 - gender_out_loss: 0.7887 - loss: 19.3885 - val_age_out_loss: 15.7232 - val_age_out_mae: 15.7232 - val_gender_out_accuracy: 0.5614 - val_gender_out_loss: 0.6898 - val_loss: 16.4130 - learning_rate: 0.0010
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 14.7836 - age_out_mae: 14.7836 - gender_out_accuracy: 0.5548 - gender_out_loss: 0.6799 - loss: 15.4635
# Epoch 2: val_gender_out_accuracy improved from 0.56137 to 0.71447, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 462s 3s/step - age_out_loss: 14.7823 - age_out_mae: 14.7823 - gender_out_accuracy: 0.5550 - gender_out_loss: 0.6797 - loss: 15.4620 - val_age_out_loss: 13.9995 - val_age_out_mae: 13.9995 - val_gender_out_accuracy: 0.7145 - val_gender_out_loss: 0.5610 - val_loss: 14.5606 - learning_rate: 9.0000e-04
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 13.3260 - age_out_mae: 13.3260 - gender_out_accuracy: 0.7239 - gender_out_loss: 0.5495 - loss: 13.8755
# Epoch 3: val_gender_out_accuracy improved from 0.71447 to 0.77351, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 420s 3s/step - age_out_loss: 13.3205 - age_out_mae: 13.3205 - gender_out_accuracy: 0.7240 - gender_out_loss: 0.5493 - loss: 13.8698 - val_age_out_loss: 11.5630 - val_age_out_mae: 11.5630 - val_gender_out_accuracy: 0.7735 - val_gender_out_loss: 0.4602 - val_loss: 12.0232 - learning_rate: 8.1000e-04
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 11.1334 - age_out_mae: 11.1334 - gender_out_accuracy: 0.7758 - gender_out_loss: 0.4667 - loss: 11.6001
# Epoch 4: val_gender_out_accuracy improved from 0.77351 to 0.81400, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 415s 3s/step - age_out_loss: 11.1310 - age_out_mae: 11.1310 - gender_out_accuracy: 0.7758 - gender_out_loss: 0.4666 - loss: 11.5976 - val_age_out_loss: 9.7483 - val_age_out_mae: 9.7483 - val_gender_out_accuracy: 0.8140 - val_gender_out_loss: 0.4092 - val_loss: 10.1575 - learning_rate: 7.2900e-04
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 10.1238 - age_out_mae: 10.1238 - gender_out_accuracy: 0.8001 - gender_out_loss: 0.4191 - loss: 10.5429
# Epoch 5: val_gender_out_accuracy improved from 0.81400 to 0.82666, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 407s 3s/step - age_out_loss: 10.1218 - age_out_mae: 10.1218 - gender_out_accuracy: 0.8001 - gender_out_loss: 0.4191 - loss: 10.5409 - val_age_out_loss: 10.7187 - val_age_out_mae: 10.7187 - val_gender_out_accuracy: 0.8267 - val_gender_out_loss: 0.3844 - val_loss: 11.1031 - learning_rate: 6.5610e-04
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 9.4109 - age_out_mae: 9.4109 - gender_out_accuracy: 0.8212 - gender_out_loss: 0.3850 - loss: 9.7959
# Epoch 6: val_gender_out_accuracy improved from 0.82666 to 0.84985, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - age_out_loss: 9.4099 - age_out_mae: 9.4099 - gender_out_accuracy: 0.8212 - gender_out_loss: 0.3850 - loss: 9.7950 - val_age_out_loss: 8.7669 - val_age_out_mae: 8.7669 - val_gender_out_accuracy: 0.8499 - val_gender_out_loss: 0.3494 - val_loss: 9.1163 - learning_rate: 5.9049e-04
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.8342 - age_out_mae: 8.8342 - gender_out_accuracy: 0.8325 - gender_out_loss: 0.3689 - loss: 9.2032
# Epoch 7: val_gender_out_accuracy did not improve from 0.84985
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - age_out_loss: 8.8337 - age_out_mae: 8.8337 - gender_out_accuracy: 0.8325 - gender_out_loss: 0.3689 - loss: 9.2026 - val_age_out_loss: 8.4120 - val_age_out_mae: 8.4120 - val_gender_out_accuracy: 0.8477 - val_gender_out_loss: 0.3433 - val_loss: 8.7553 - learning_rate: 5.3144e-04
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.4058 - age_out_mae: 8.4058 - gender_out_accuracy: 0.8430 - gender_out_loss: 0.3470 - loss: 8.7528
# Epoch 8: val_gender_out_accuracy improved from 0.84985 to 0.85955, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - age_out_loss: 8.4048 - age_out_mae: 8.4048 - gender_out_accuracy: 0.8430 - gender_out_loss: 0.3470 - loss: 8.7518 - val_age_out_loss: 8.1561 - val_age_out_mae: 8.1561 - val_gender_out_accuracy: 0.8596 - val_gender_out_loss: 0.3171 - val_loss: 8.4733 - learning_rate: 4.7830e-04
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.9336 - age_out_mae: 7.9336 - gender_out_accuracy: 0.8557 - gender_out_loss: 0.3231 - loss: 8.2567
# Epoch 9: val_gender_out_accuracy improved from 0.85955 to 0.86251, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 313s 2s/step - age_out_loss: 7.9335 - age_out_mae: 7.9335 - gender_out_accuracy: 0.8556 - gender_out_loss: 0.3231 - loss: 8.2567 - val_age_out_loss: 7.8499 - val_age_out_mae: 7.8499 - val_gender_out_accuracy: 0.8625 - val_gender_out_loss: 0.3112 - val_loss: 8.1611 - learning_rate: 4.3047e-04
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.7079 - age_out_mae: 7.7079 - gender_out_accuracy: 0.8561 - gender_out_loss: 0.3221 - loss: 8.0300
# Epoch 10: val_gender_out_accuracy improved from 0.86251 to 0.87094, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - age_out_loss: 7.7081 - age_out_mae: 7.7081 - gender_out_accuracy: 0.8561 - gender_out_loss: 0.3221 - loss: 8.0302 - val_age_out_loss: 7.5280 - val_age_out_mae: 7.5280 - val_gender_out_accuracy: 0.8709 - val_gender_out_loss: 0.2983 - val_loss: 7.8263 - learning_rate: 3.8742e-04
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.6099 - age_out_mae: 7.6099 - gender_out_accuracy: 0.8655 - gender_out_loss: 0.3044 - loss: 7.9143
# Epoch 11: val_gender_out_accuracy did not improve from 0.87094
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - age_out_loss: 7.6093 - age_out_mae: 7.6093 - gender_out_accuracy: 0.8655 - gender_out_loss: 0.3044 - loss: 7.9137 - val_age_out_loss: 7.3766 - val_age_out_mae: 7.3766 - val_gender_out_accuracy: 0.8684 - val_gender_out_loss: 0.3001 - val_loss: 7.6767 - learning_rate: 3.4868e-04
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.3203 - age_out_mae: 7.3203 - gender_out_accuracy: 0.8711 - gender_out_loss: 0.2868 - loss: 7.6070
# Epoch 12: val_gender_out_accuracy improved from 0.87094 to 0.87431, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 299s 2s/step - age_out_loss: 7.3199 - age_out_mae: 7.3199 - gender_out_accuracy: 0.8711 - gender_out_loss: 0.2868 - loss: 7.6067 - val_age_out_loss: 7.3989 - val_age_out_mae: 7.3989 - val_gender_out_accuracy: 0.8743 - val_gender_out_loss: 0.2913 - val_loss: 7.6902 - learning_rate: 3.1381e-04
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.1306 - age_out_mae: 7.1306 - gender_out_accuracy: 0.8731 - gender_out_loss: 0.2830 - loss: 7.4135
# Epoch 13: val_gender_out_accuracy improved from 0.87431 to 0.88022, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - age_out_loss: 7.1309 - age_out_mae: 7.1309 - gender_out_accuracy: 0.8731 - gender_out_loss: 0.2830 - loss: 7.4139 - val_age_out_loss: 7.2384 - val_age_out_mae: 7.2384 - val_gender_out_accuracy: 0.8802 - val_gender_out_loss: 0.2813 - val_loss: 7.5197 - learning_rate: 2.8243e-04
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.0428 - age_out_mae: 7.0428 - gender_out_accuracy: 0.8743 - gender_out_loss: 0.2793 - loss: 7.3221
# Epoch 14: val_gender_out_accuracy improved from 0.88022 to 0.88191, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - age_out_loss: 7.0425 - age_out_mae: 7.0425 - gender_out_accuracy: 0.8743 - gender_out_loss: 0.2793 - loss: 7.3218 - val_age_out_loss: 7.1416 - val_age_out_mae: 7.1416 - val_gender_out_accuracy: 0.8819 - val_gender_out_loss: 0.2799 - val_loss: 7.4215 - learning_rate: 2.5419e-04
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.8947 - age_out_mae: 6.8947 - gender_out_accuracy: 0.8790 - gender_out_loss: 0.2710 - loss: 7.1657
# Epoch 15: val_gender_out_accuracy improved from 0.88191 to 0.88317, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 317s 2s/step - age_out_loss: 6.8943 - age_out_mae: 6.8943 - gender_out_accuracy: 0.8790 - gender_out_loss: 0.2710 - loss: 7.1654 - val_age_out_loss: 7.1487 - val_age_out_mae: 7.1487 - val_gender_out_accuracy: 0.8832 - val_gender_out_loss: 0.2725 - val_loss: 7.4212 - learning_rate: 2.2877e-04
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.7514 - age_out_mae: 6.7514 - gender_out_accuracy: 0.8831 - gender_out_loss: 0.2616 - loss: 7.0130
# Epoch 16: val_gender_out_accuracy improved from 0.88317 to 0.88655, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 307s 2s/step - age_out_loss: 6.7514 - age_out_mae: 6.7514 - gender_out_accuracy: 0.8830 - gender_out_loss: 0.2616 - loss: 7.0130 - val_age_out_loss: 7.0667 - val_age_out_mae: 7.0667 - val_gender_out_accuracy: 0.8865 - val_gender_out_loss: 0.2710 - val_loss: 7.3376 - learning_rate: 2.0589e-04
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.6982 - age_out_mae: 6.6982 - gender_out_accuracy: 0.8854 - gender_out_loss: 0.2610 - loss: 6.9592
# Epoch 17: val_gender_out_accuracy did not improve from 0.88655
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - age_out_loss: 6.6980 - age_out_mae: 6.6980 - gender_out_accuracy: 0.8854 - gender_out_loss: 0.2610 - loss: 6.9590 - val_age_out_loss: 7.1411 - val_age_out_mae: 7.1411 - val_gender_out_accuracy: 0.8849 - val_gender_out_loss: 0.2710 - val_loss: 7.4121 - learning_rate: 1.8530e-04
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.6267 - age_out_mae: 6.6267 - gender_out_accuracy: 0.8856 - gender_out_loss: 0.2628 - loss: 6.8895
# Epoch 18: val_gender_out_accuracy did not improve from 0.88655
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - age_out_loss: 6.6268 - age_out_mae: 6.6268 - gender_out_accuracy: 0.8856 - gender_out_loss: 0.2628 - loss: 6.8896 - val_age_out_loss: 7.4282 - val_age_out_mae: 7.4282 - val_gender_out_accuracy: 0.8865 - val_gender_out_loss: 0.2684 - val_loss: 7.6966 - learning_rate: 1.6677e-04
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.5052 - age_out_mae: 6.5052 - gender_out_accuracy: 0.8908 - gender_out_loss: 0.2542 - loss: 6.7594
# Epoch 19: val_gender_out_accuracy did not improve from 0.88655
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - age_out_loss: 6.5053 - age_out_mae: 6.5053 - gender_out_accuracy: 0.8907 - gender_out_loss: 0.2542 - loss: 6.7595 - val_age_out_loss: 6.8359 - val_age_out_mae: 6.8359 - val_gender_out_accuracy: 0.8865 - val_gender_out_loss: 0.2681 - val_loss: 7.1040 - learning_rate: 1.5009e-04
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.3128 - age_out_mae: 6.3128 - gender_out_accuracy: 0.8891 - gender_out_loss: 0.2488 - loss: 6.5616
# Epoch 20: val_gender_out_accuracy improved from 0.88655 to 0.89203, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - age_out_loss: 6.3134 - age_out_mae: 6.3134 - gender_out_accuracy: 0.8891 - gender_out_loss: 0.2488 - loss: 6.5622 - val_age_out_loss: 7.2092 - val_age_out_mae: 7.2092 - val_gender_out_accuracy: 0.8920 - val_gender_out_loss: 0.2639 - val_loss: 7.4732 - learning_rate: 1.3509e-04
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.3849 - age_out_mae: 6.3849 - gender_out_accuracy: 0.8914 - gender_out_loss: 0.2452 - loss: 6.6301
# Epoch 21: val_gender_out_accuracy improved from 0.89203 to 0.89287, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - age_out_loss: 6.3847 - age_out_mae: 6.3847 - gender_out_accuracy: 0.8914 - gender_out_loss: 0.2452 - loss: 6.6300 - val_age_out_loss: 7.0116 - val_age_out_mae: 7.0116 - val_gender_out_accuracy: 0.8929 - val_gender_out_loss: 0.2637 - val_loss: 7.2752 - learning_rate: 1.2158e-04
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.3727 - age_out_mae: 6.3727 - gender_out_accuracy: 0.8944 - gender_out_loss: 0.2437 - loss: 6.6163
# Epoch 22: val_gender_out_accuracy improved from 0.89287 to 0.89709, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - age_out_loss: 6.3726 - age_out_mae: 6.3726 - gender_out_accuracy: 0.8944 - gender_out_loss: 0.2437 - loss: 6.6163 - val_age_out_loss: 7.1264 - val_age_out_mae: 7.1264 - val_gender_out_accuracy: 0.8971 - val_gender_out_loss: 0.2605 - val_loss: 7.3869 - learning_rate: 1.0942e-04
# Epoch 23/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.2226 - age_out_mae: 6.2226 - gender_out_accuracy: 0.8948 - gender_out_loss: 0.2470 - loss: 6.4696
# Epoch 23: val_gender_out_accuracy did not improve from 0.89709
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - age_out_loss: 6.2228 - age_out_mae: 6.2228 - gender_out_accuracy: 0.8948 - gender_out_loss: 0.2469 - loss: 6.4697 - val_age_out_loss: 6.8639 - val_age_out_mae: 6.8639 - val_gender_out_accuracy: 0.8937 - val_gender_out_loss: 0.2599 - val_loss: 7.1238 - learning_rate: 9.8477e-05
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.2047 - age_out_mae: 6.2047 - gender_out_accuracy: 0.8946 - gender_out_loss: 0.2451 - loss: 6.4497
# Epoch 24: val_gender_out_accuracy did not improve from 0.89709
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 315s 2s/step - age_out_loss: 6.2048 - age_out_mae: 6.2048 - gender_out_accuracy: 0.8946 - gender_out_loss: 0.2450 - loss: 6.4499 - val_age_out_loss: 6.7342 - val_age_out_mae: 6.7342 - val_gender_out_accuracy: 0.8946 - val_gender_out_loss: 0.2614 - val_loss: 6.9956 - learning_rate: 8.8629e-05
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.1313 - age_out_mae: 6.1313 - gender_out_accuracy: 0.8957 - gender_out_loss: 0.2436 - loss: 6.3749
# Epoch 25: val_gender_out_accuracy improved from 0.89709 to 0.89836, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - age_out_loss: 6.1316 - age_out_mae: 6.1316 - gender_out_accuracy: 0.8957 - gender_out_loss: 0.2436 - loss: 6.3752 - val_age_out_loss: 6.6853 - val_age_out_mae: 6.6853 - val_gender_out_accuracy: 0.8984 - val_gender_out_loss: 0.2579 - val_loss: 6.9432 - learning_rate: 7.9766e-05
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.0856 - age_out_mae: 6.0856 - gender_out_accuracy: 0.8998 - gender_out_loss: 0.2388 - loss: 6.3244
# Epoch 26: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 315s 2s/step - age_out_loss: 6.0859 - age_out_mae: 6.0859 - gender_out_accuracy: 0.8998 - gender_out_loss: 0.2387 - loss: 6.3246 - val_age_out_loss: 6.7109 - val_age_out_mae: 6.7109 - val_gender_out_accuracy: 0.8958 - val_gender_out_loss: 0.2573 - val_loss: 6.9682 - learning_rate: 7.1790e-05
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.0473 - age_out_mae: 6.0473 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2363 - loss: 6.2835
# Epoch 27: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - age_out_loss: 6.0474 - age_out_mae: 6.0474 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2363 - loss: 6.2837 - val_age_out_loss: 6.7074 - val_age_out_mae: 6.7074 - val_gender_out_accuracy: 0.8954 - val_gender_out_loss: 0.2565 - val_loss: 6.9639 - learning_rate: 6.4611e-05
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.0754 - age_out_mae: 6.0754 - gender_out_accuracy: 0.9008 - gender_out_loss: 0.2348 - loss: 6.3102
# Epoch 28: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - age_out_loss: 6.0756 - age_out_mae: 6.0756 - gender_out_accuracy: 0.9008 - gender_out_loss: 0.2348 - loss: 6.3104 - val_age_out_loss: 6.6617 - val_age_out_mae: 6.6617 - val_gender_out_accuracy: 0.8979 - val_gender_out_loss: 0.2565 - val_loss: 6.9182 - learning_rate: 5.8150e-05
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9653 - age_out_mae: 5.9653 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2258 - loss: 6.1911
# Epoch 29: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - age_out_loss: 5.9658 - age_out_mae: 5.9658 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2258 - loss: 6.1916 - val_age_out_loss: 6.6612 - val_age_out_mae: 6.6612 - val_gender_out_accuracy: 0.8941 - val_gender_out_loss: 0.2574 - val_loss: 6.9187 - learning_rate: 5.2335e-05
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9324 - age_out_mae: 5.9324 - gender_out_accuracy: 0.9014 - gender_out_loss: 0.2227 - loss: 6.1550
# Epoch 30: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 415s 3s/step - age_out_loss: 5.9329 - age_out_mae: 5.9329 - gender_out_accuracy: 0.9014 - gender_out_loss: 0.2227 - loss: 6.1557 - val_age_out_loss: 6.6547 - val_age_out_mae: 6.6547 - val_gender_out_accuracy: 0.8962 - val_gender_out_loss: 0.2547 - val_loss: 6.9094 - learning_rate: 4.7101e-05
# Epoch 31/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9877 - age_out_mae: 5.9877 - gender_out_accuracy: 0.9027 - gender_out_loss: 0.2318 - loss: 6.2195
# Epoch 31: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - age_out_loss: 5.9876 - age_out_mae: 5.9876 - gender_out_accuracy: 0.9027 - gender_out_loss: 0.2318 - loss: 6.2194 - val_age_out_loss: 6.6418 - val_age_out_mae: 6.6418 - val_gender_out_accuracy: 0.8979 - val_gender_out_loss: 0.2540 - val_loss: 6.8958 - learning_rate: 4.2391e-05
# Epoch 32/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9479 - age_out_mae: 5.9479 - gender_out_accuracy: 0.8998 - gender_out_loss: 0.2362 - loss: 6.1842
# Epoch 32: val_gender_out_accuracy did not improve from 0.89836
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 345s 2s/step - age_out_loss: 5.9480 - age_out_mae: 5.9480 - gender_out_accuracy: 0.8998 - gender_out_loss: 0.2362 - loss: 6.1841 - val_age_out_loss: 6.6356 - val_age_out_mae: 6.6356 - val_gender_out_accuracy: 0.8962 - val_gender_out_loss: 0.2549 - val_loss: 6.8905 - learning_rate: 3.8152e-05
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8459 - age_out_mae: 5.8459 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2249 - loss: 6.0708
# Epoch 33: val_gender_out_accuracy improved from 0.89836 to 0.89962, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - age_out_loss: 5.8466 - age_out_mae: 5.8466 - gender_out_accuracy: 0.9044 - gender_out_loss: 0.2249 - loss: 6.0714 - val_age_out_loss: 6.6876 - val_age_out_mae: 6.6876 - val_gender_out_accuracy: 0.8996 - val_gender_out_loss: 0.2551 - val_loss: 6.9427 - learning_rate: 3.4337e-05
# Epoch 34/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9149 - age_out_mae: 5.9149 - gender_out_accuracy: 0.9037 - gender_out_loss: 0.2237 - loss: 6.1386
# Epoch 34: val_gender_out_accuracy did not improve from 0.89962
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - age_out_loss: 5.9150 - age_out_mae: 5.9150 - gender_out_accuracy: 0.9037 - gender_out_loss: 0.2237 - loss: 6.1387 - val_age_out_loss: 6.6339 - val_age_out_mae: 6.6339 - val_gender_out_accuracy: 0.8996 - val_gender_out_loss: 0.2537 - val_loss: 6.8876 - learning_rate: 3.0903e-05
# Epoch 35/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8398 - age_out_mae: 5.8398 - gender_out_accuracy: 0.9029 - gender_out_loss: 0.2271 - loss: 6.0669
# Epoch 35: val_gender_out_accuracy did not improve from 0.89962
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 307s 2s/step - age_out_loss: 5.8402 - age_out_mae: 5.8402 - gender_out_accuracy: 0.9030 - gender_out_loss: 0.2271 - loss: 6.0673 - val_age_out_loss: 6.6143 - val_age_out_mae: 6.6143 - val_gender_out_accuracy: 0.8992 - val_gender_out_loss: 0.2534 - val_loss: 6.8677 - learning_rate: 2.7813e-05
# Epoch 36/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.9080 - age_out_mae: 5.9080 - gender_out_accuracy: 0.9039 - gender_out_loss: 0.2260 - loss: 6.1340
# Epoch 36: val_gender_out_accuracy did not improve from 0.89962
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - age_out_loss: 5.9079 - age_out_mae: 5.9079 - gender_out_accuracy: 0.9039 - gender_out_loss: 0.2260 - loss: 6.1339 - val_age_out_loss: 6.5979 - val_age_out_mae: 6.5979 - val_gender_out_accuracy: 0.8988 - val_gender_out_loss: 0.2535 - val_loss: 6.8514 - learning_rate: 2.5032e-05
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8546 - age_out_mae: 5.8546 - gender_out_accuracy: 0.9021 - gender_out_loss: 0.2269 - loss: 6.0815
# Epoch 37: val_gender_out_accuracy improved from 0.89962 to 0.90046, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 304s 2s/step - age_out_loss: 5.8548 - age_out_mae: 5.8548 - gender_out_accuracy: 0.9021 - gender_out_loss: 0.2269 - loss: 6.0817 - val_age_out_loss: 6.5985 - val_age_out_mae: 6.5985 - val_gender_out_accuracy: 0.9005 - val_gender_out_loss: 0.2532 - val_loss: 6.8517 - learning_rate: 2.2528e-05
# Epoch 38/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8634 - age_out_mae: 5.8634 - gender_out_accuracy: 0.9032 - gender_out_loss: 0.2278 - loss: 6.0912
# Epoch 38: val_gender_out_accuracy did not improve from 0.90046
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - age_out_loss: 5.8635 - age_out_mae: 5.8635 - gender_out_accuracy: 0.9032 - gender_out_loss: 0.2278 - loss: 6.0913 - val_age_out_loss: 6.6007 - val_age_out_mae: 6.6007 - val_gender_out_accuracy: 0.9000 - val_gender_out_loss: 0.2527 - val_loss: 6.8534 - learning_rate: 2.0276e-05
# Epoch 39/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8483 - age_out_mae: 5.8483 - gender_out_accuracy: 0.9085 - gender_out_loss: 0.2180 - loss: 6.0664
# Epoch 39: val_gender_out_accuracy did not improve from 0.90046
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 299s 2s/step - age_out_loss: 5.8484 - age_out_mae: 5.8484 - gender_out_accuracy: 0.9084 - gender_out_loss: 0.2181 - loss: 6.0665 - val_age_out_loss: 6.6025 - val_age_out_mae: 6.6025 - val_gender_out_accuracy: 0.9005 - val_gender_out_loss: 0.2523 - val_loss: 6.8547 - learning_rate: 1.8248e-05
# Epoch 40/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8179 - age_out_mae: 5.8179 - gender_out_accuracy: 0.9098 - gender_out_loss: 0.2203 - loss: 6.0382
# Epoch 40: val_gender_out_accuracy did not improve from 0.90046
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - age_out_loss: 5.8181 - age_out_mae: 5.8181 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2203 - loss: 6.0384 - val_age_out_loss: 6.6028 - val_age_out_mae: 6.6028 - val_gender_out_accuracy: 0.9000 - val_gender_out_loss: 0.2533 - val_loss: 6.8560 - learning_rate: 1.6423e-05
# Epoch 41/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8665 - age_out_mae: 5.8665 - gender_out_accuracy: 0.9084 - gender_out_loss: 0.2234 - loss: 6.0899
# Epoch 41: val_gender_out_accuracy did not improve from 0.90046
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - age_out_loss: 5.8663 - age_out_mae: 5.8663 - gender_out_accuracy: 0.9084 - gender_out_loss: 0.2234 - loss: 6.0896 - val_age_out_loss: 6.5942 - val_age_out_mae: 6.5942 - val_gender_out_accuracy: 0.8992 - val_gender_out_loss: 0.2525 - val_loss: 6.8467 - learning_rate: 1.4781e-05
# Epoch 42/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8217 - age_out_mae: 5.8217 - gender_out_accuracy: 0.9106 - gender_out_loss: 0.2114 - loss: 6.0331
# Epoch 42: val_gender_out_accuracy improved from 0.90046 to 0.90131, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - age_out_loss: 5.8217 - age_out_mae: 5.8217 - gender_out_accuracy: 0.9106 - gender_out_loss: 0.2114 - loss: 6.0332 - val_age_out_loss: 6.5937 - val_age_out_mae: 6.5937 - val_gender_out_accuracy: 0.9013 - val_gender_out_loss: 0.2520 - val_loss: 6.8457 - learning_rate: 1.3303e-05
# Epoch 43/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8366 - age_out_mae: 5.8366 - gender_out_accuracy: 0.9088 - gender_out_loss: 0.2234 - loss: 6.0600
# Epoch 43: val_gender_out_accuracy did not improve from 0.90131
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - age_out_loss: 5.8364 - age_out_mae: 5.8364 - gender_out_accuracy: 0.9088 - gender_out_loss: 0.2234 - loss: 6.0598 - val_age_out_loss: 6.5753 - val_age_out_mae: 6.5753 - val_gender_out_accuracy: 0.9009 - val_gender_out_loss: 0.2519 - val_loss: 6.8272 - learning_rate: 1.1973e-05
# Epoch 44/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8265 - age_out_mae: 5.8265 - gender_out_accuracy: 0.9082 - gender_out_loss: 0.2207 - loss: 6.0472
# Epoch 44: val_gender_out_accuracy did not improve from 0.90131
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - age_out_loss: 5.8263 - age_out_mae: 5.8263 - gender_out_accuracy: 0.9083 - gender_out_loss: 0.2207 - loss: 6.0470 - val_age_out_loss: 6.5790 - val_age_out_mae: 6.5790 - val_gender_out_accuracy: 0.9005 - val_gender_out_loss: 0.2518 - val_loss: 6.8308 - learning_rate: 1.0775e-05
# Epoch 45/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8193 - age_out_mae: 5.8193 - gender_out_accuracy: 0.9061 - gender_out_loss: 0.2292 - loss: 6.0485
# Epoch 45: val_gender_out_accuracy did not improve from 0.90131
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - age_out_loss: 5.8195 - age_out_mae: 5.8195 - gender_out_accuracy: 0.9061 - gender_out_loss: 0.2291 - loss: 6.0486 - val_age_out_loss: 6.5796 - val_age_out_mae: 6.5796 - val_gender_out_accuracy: 0.9013 - val_gender_out_loss: 0.2527 - val_loss: 6.8323 - learning_rate: 9.6977e-06
# Epoch 46/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7631 - age_out_mae: 5.7631 - gender_out_accuracy: 0.9062 - gender_out_loss: 0.2199 - loss: 5.9829
# Epoch 46: val_gender_out_accuracy improved from 0.90131 to 0.90173, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - age_out_loss: 5.7635 - age_out_mae: 5.7635 - gender_out_accuracy: 0.9062 - gender_out_loss: 0.2199 - loss: 5.9834 - val_age_out_loss: 6.5764 - val_age_out_mae: 6.5764 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2522 - val_loss: 6.8286 - learning_rate: 8.7280e-06
# Epoch 47/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8066 - age_out_mae: 5.8066 - gender_out_accuracy: 0.9150 - gender_out_loss: 0.2111 - loss: 6.0177
# Epoch 47: val_gender_out_accuracy did not improve from 0.90173
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - age_out_loss: 5.8065 - age_out_mae: 5.8065 - gender_out_accuracy: 0.9150 - gender_out_loss: 0.2112 - loss: 6.0177 - val_age_out_loss: 6.5823 - val_age_out_mae: 6.5823 - val_gender_out_accuracy: 0.9000 - val_gender_out_loss: 0.2524 - val_loss: 6.8347 - learning_rate: 7.8552e-06
# Epoch 48/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8043 - age_out_mae: 5.8043 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2148 - loss: 6.0191
# Epoch 48: val_gender_out_accuracy did not improve from 0.90173
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 312s 2s/step - age_out_loss: 5.8043 - age_out_mae: 5.8043 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2148 - loss: 6.0191 - val_age_out_loss: 6.5620 - val_age_out_mae: 6.5620 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2522 - val_loss: 6.8142 - learning_rate: 7.0697e-06
# Epoch 49/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8028 - age_out_mae: 5.8028 - gender_out_accuracy: 0.9105 - gender_out_loss: 0.2184 - loss: 6.0213
# Epoch 49: val_gender_out_accuracy did not improve from 0.90173
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - age_out_loss: 5.8029 - age_out_mae: 5.8029 - gender_out_accuracy: 0.9105 - gender_out_loss: 0.2184 - loss: 6.0214 - val_age_out_loss: 6.5653 - val_age_out_mae: 6.5653 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2519 - val_loss: 6.8172 - learning_rate: 6.3627e-06
# Epoch 50/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7940 - age_out_mae: 5.7940 - gender_out_accuracy: 0.9090 - gender_out_loss: 0.2164 - loss: 6.0104
# Epoch 50: val_gender_out_accuracy did not improve from 0.90173
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - age_out_loss: 5.7940 - age_out_mae: 5.7940 - gender_out_accuracy: 0.9090 - gender_out_loss: 0.2164 - loss: 6.0104 - val_age_out_loss: 6.5654 - val_age_out_mae: 6.5654 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2517 - val_loss: 6.8171 - learning_rate: 5.7264e-06
# Epoch 51/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7068 - age_out_mae: 5.7068 - gender_out_accuracy: 0.9112 - gender_out_loss: 0.2174 - loss: 5.9243
# Epoch 51: val_gender_out_accuracy improved from 0.90173 to 0.90299, saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - age_out_loss: 5.7072 - age_out_mae: 5.7072 - gender_out_accuracy: 0.9112 - gender_out_loss: 0.2174 - loss: 5.9246 - val_age_out_loss: 6.5633 - val_age_out_mae: 6.5633 - val_gender_out_accuracy: 0.9030 - val_gender_out_loss: 0.2516 - val_loss: 6.8149 - learning_rate: 5.1538e-06
# Epoch 52/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8044 - age_out_mae: 5.8044 - gender_out_accuracy: 0.9096 - gender_out_loss: 0.2197 - loss: 6.0241
# Epoch 52: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - age_out_loss: 5.8042 - age_out_mae: 5.8042 - gender_out_accuracy: 0.9096 - gender_out_loss: 0.2197 - loss: 6.0238 - val_age_out_loss: 6.5803 - val_age_out_mae: 6.5803 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2519 - val_loss: 6.8323 - learning_rate: 4.6384e-06
# Epoch 53/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7882 - age_out_mae: 5.7882 - gender_out_accuracy: 0.9071 - gender_out_loss: 0.2161 - loss: 6.0043
# Epoch 53: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - age_out_loss: 5.7882 - age_out_mae: 5.7882 - gender_out_accuracy: 0.9071 - gender_out_loss: 0.2161 - loss: 6.0044 - val_age_out_loss: 6.5636 - val_age_out_mae: 6.5636 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2517 - val_loss: 6.8152 - learning_rate: 4.1746e-06
# Epoch 54/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7276 - age_out_mae: 5.7276 - gender_out_accuracy: 0.9066 - gender_out_loss: 0.2163 - loss: 5.9439
# Epoch 54: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - age_out_loss: 5.7281 - age_out_mae: 5.7281 - gender_out_accuracy: 0.9066 - gender_out_loss: 0.2163 - loss: 5.9444 - val_age_out_loss: 6.5621 - val_age_out_mae: 6.5621 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2517 - val_loss: 6.8138 - learning_rate: 3.7571e-06
# Epoch 55/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8482 - age_out_mae: 5.8482 - gender_out_accuracy: 0.9092 - gender_out_loss: 0.2161 - loss: 6.0643
# Epoch 55: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - age_out_loss: 5.8478 - age_out_mae: 5.8478 - gender_out_accuracy: 0.9092 - gender_out_loss: 0.2161 - loss: 6.0639 - val_age_out_loss: 6.5607 - val_age_out_mae: 6.5607 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8123 - learning_rate: 3.3814e-06
# Epoch 56/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7434 - age_out_mae: 5.7434 - gender_out_accuracy: 0.9084 - gender_out_loss: 0.2212 - loss: 5.9647
# Epoch 56: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - age_out_loss: 5.7436 - age_out_mae: 5.7436 - gender_out_accuracy: 0.9084 - gender_out_loss: 0.2212 - loss: 5.9648 - val_age_out_loss: 6.5589 - val_age_out_mae: 6.5589 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2517 - val_loss: 6.8106 - learning_rate: 3.0433e-06
# Epoch 57/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8656 - age_out_mae: 5.8656 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2138 - loss: 6.0794
# Epoch 57: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - age_out_loss: 5.8651 - age_out_mae: 5.8651 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2139 - loss: 6.0789 - val_age_out_loss: 6.5599 - val_age_out_mae: 6.5599 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2517 - val_loss: 6.8116 - learning_rate: 2.7389e-06
# Epoch 58/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7081 - age_out_mae: 5.7081 - gender_out_accuracy: 0.9085 - gender_out_loss: 0.2202 - loss: 5.9283
# Epoch 58: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - age_out_loss: 5.7085 - age_out_mae: 5.7085 - gender_out_accuracy: 0.9085 - gender_out_loss: 0.2202 - loss: 5.9287 - val_age_out_loss: 6.5620 - val_age_out_mae: 6.5620 - val_gender_out_accuracy: 0.9030 - val_gender_out_loss: 0.2516 - val_loss: 6.8136 - learning_rate: 2.4650e-06
# Epoch 59/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7323 - age_out_mae: 5.7323 - gender_out_accuracy: 0.9052 - gender_out_loss: 0.2161 - loss: 5.9484
# Epoch 59: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - age_out_loss: 5.7326 - age_out_mae: 5.7326 - gender_out_accuracy: 0.9052 - gender_out_loss: 0.2161 - loss: 5.9487 - val_age_out_loss: 6.5600 - val_age_out_mae: 6.5600 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2516 - val_loss: 6.8116 - learning_rate: 2.2185e-06
# Epoch 60/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8182 - age_out_mae: 5.8182 - gender_out_accuracy: 0.9069 - gender_out_loss: 0.2220 - loss: 6.0402
# Epoch 60: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - age_out_loss: 5.8178 - age_out_mae: 5.8178 - gender_out_accuracy: 0.9069 - gender_out_loss: 0.2219 - loss: 6.0397 - val_age_out_loss: 6.5602 - val_age_out_mae: 6.5602 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2517 - val_loss: 6.8119 - learning_rate: 1.9967e-06
# Epoch 61/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8134 - age_out_mae: 5.8134 - gender_out_accuracy: 0.9127 - gender_out_loss: 0.2189 - loss: 6.0324
# Epoch 61: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - age_out_loss: 5.8131 - age_out_mae: 5.8131 - gender_out_accuracy: 0.9127 - gender_out_loss: 0.2189 - loss: 6.0321 - val_age_out_loss: 6.5586 - val_age_out_mae: 6.5586 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2516 - val_loss: 6.8102 - learning_rate: 1.7970e-06
# Epoch 62/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7333 - age_out_mae: 5.7333 - gender_out_accuracy: 0.9100 - gender_out_loss: 0.2183 - loss: 5.9516
# Epoch 62: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - age_out_loss: 5.7337 - age_out_mae: 5.7337 - gender_out_accuracy: 0.9100 - gender_out_loss: 0.2183 - loss: 5.9520 - val_age_out_loss: 6.5614 - val_age_out_mae: 6.5614 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2517 - val_loss: 6.8131 - learning_rate: 1.6173e-06
# Epoch 63/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8378 - age_out_mae: 5.8378 - gender_out_accuracy: 0.9072 - gender_out_loss: 0.2233 - loss: 6.0611
# Epoch 63: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 308s 2s/step - age_out_loss: 5.8372 - age_out_mae: 5.8372 - gender_out_accuracy: 0.9072 - gender_out_loss: 0.2233 - loss: 6.0605 - val_age_out_loss: 6.5598 - val_age_out_mae: 6.5598 - val_gender_out_accuracy: 0.9030 - val_gender_out_loss: 0.2516 - val_loss: 6.8114 - learning_rate: 1.4556e-06
# Epoch 64/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7397 - age_out_mae: 5.7397 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2126 - loss: 5.9523
# Epoch 64: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - age_out_loss: 5.7399 - age_out_mae: 5.7399 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2126 - loss: 5.9525 - val_age_out_loss: 6.5599 - val_age_out_mae: 6.5599 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2517 - val_loss: 6.8116 - learning_rate: 1.3100e-06
# Epoch 65/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.6964 - age_out_mae: 5.6964 - gender_out_accuracy: 0.9116 - gender_out_loss: 0.2107 - loss: 5.9071
# Epoch 65: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - age_out_loss: 5.6968 - age_out_mae: 5.6968 - gender_out_accuracy: 0.9115 - gender_out_loss: 0.2107 - loss: 5.9075 - val_age_out_loss: 6.5594 - val_age_out_mae: 6.5594 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2517 - val_loss: 6.8111 - learning_rate: 1.1790e-06
# Epoch 66/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7609 - age_out_mae: 5.7609 - gender_out_accuracy: 0.9079 - gender_out_loss: 0.2194 - loss: 5.9803
# Epoch 66: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - age_out_loss: 5.7609 - age_out_mae: 5.7609 - gender_out_accuracy: 0.9079 - gender_out_loss: 0.2194 - loss: 5.9802 - val_age_out_loss: 6.5586 - val_age_out_mae: 6.5586 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2517 - val_loss: 6.8103 - learning_rate: 1.0611e-06
# Epoch 67/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 5.7888 - age_out_mae: 5.7888 - gender_out_accuracy: 0.9042 - gender_out_loss: 0.2245 - loss: 6.0132
# Epoch 67: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 418s 3s/step - age_out_loss: 5.7887 - age_out_mae: 5.7887 - gender_out_accuracy: 0.9042 - gender_out_loss: 0.2244 - loss: 6.0131 - val_age_out_loss: 6.5587 - val_age_out_mae: 6.5587 - val_gender_out_accuracy: 0.9030 - val_gender_out_loss: 0.2516 - val_loss: 6.8102 - learning_rate: 9.5500e-07
# Epoch 68/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 5.7595 - age_out_mae: 5.7595 - gender_out_accuracy: 0.9096 - gender_out_loss: 0.2172 - loss: 5.9767
# Epoch 68: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 418s 3s/step - age_out_loss: 5.7595 - age_out_mae: 5.7595 - gender_out_accuracy: 0.9096 - gender_out_loss: 0.2172 - loss: 5.9767 - val_age_out_loss: 6.5587 - val_age_out_mae: 6.5587 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2516 - val_loss: 6.8102 - learning_rate: 8.5950e-07
# Epoch 69/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7813 - age_out_mae: 5.7813 - gender_out_accuracy: 0.9089 - gender_out_loss: 0.2189 - loss: 6.0002
# Epoch 69: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 310s 2s/step - age_out_loss: 5.7812 - age_out_mae: 5.7812 - gender_out_accuracy: 0.9089 - gender_out_loss: 0.2189 - loss: 6.0001 - val_age_out_loss: 6.5585 - val_age_out_mae: 6.5585 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2516 - val_loss: 6.8101 - learning_rate: 7.7355e-07
# Epoch 70/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7089 - age_out_mae: 5.7089 - gender_out_accuracy: 0.9046 - gender_out_loss: 0.2230 - loss: 5.9319
# Epoch 70: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - age_out_loss: 5.7091 - age_out_mae: 5.7091 - gender_out_accuracy: 0.9047 - gender_out_loss: 0.2229 - loss: 5.9321 - val_age_out_loss: 6.5588 - val_age_out_mae: 6.5588 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2515 - val_loss: 6.8103 - learning_rate: 6.9620e-07
# Epoch 71/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 5.7297 - age_out_mae: 5.7297 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2161 - loss: 5.9458
# Epoch 71: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 441s 3s/step - age_out_loss: 5.7301 - age_out_mae: 5.7301 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2161 - loss: 5.9462 - val_age_out_loss: 6.5582 - val_age_out_mae: 6.5582 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2516 - val_loss: 6.8098 - learning_rate: 6.2658e-07
# Epoch 72/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7819 - age_out_mae: 5.7819 - gender_out_accuracy: 0.9125 - gender_out_loss: 0.2125 - loss: 5.9944
# Epoch 72: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - age_out_loss: 5.7818 - age_out_mae: 5.7818 - gender_out_accuracy: 0.9125 - gender_out_loss: 0.2126 - loss: 5.9943 - val_age_out_loss: 6.5575 - val_age_out_mae: 6.5575 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2516 - val_loss: 6.8090 - learning_rate: 5.6392e-07
# Epoch 73/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8110 - age_out_mae: 5.8110 - gender_out_accuracy: 0.9108 - gender_out_loss: 0.2192 - loss: 6.0302
# Epoch 73: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - age_out_loss: 5.8106 - age_out_mae: 5.8106 - gender_out_accuracy: 0.9108 - gender_out_loss: 0.2192 - loss: 6.0298 - val_age_out_loss: 6.5575 - val_age_out_mae: 6.5575 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8090 - learning_rate: 5.0753e-07
# Epoch 74/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 5.7525 - age_out_mae: 5.7525 - gender_out_accuracy: 0.9076 - gender_out_loss: 0.2209 - loss: 5.9734
# Epoch 74: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 400s 3s/step - age_out_loss: 5.7528 - age_out_mae: 5.7528 - gender_out_accuracy: 0.9076 - gender_out_loss: 0.2208 - loss: 5.9736 - val_age_out_loss: 6.5571 - val_age_out_mae: 6.5571 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2516 - val_loss: 6.8087 - learning_rate: 4.5678e-07
# Epoch 75/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8295 - age_out_mae: 5.8295 - gender_out_accuracy: 0.9119 - gender_out_loss: 0.2148 - loss: 6.0443
# Epoch 75: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 379s 2s/step - age_out_loss: 5.8291 - age_out_mae: 5.8291 - gender_out_accuracy: 0.9119 - gender_out_loss: 0.2148 - loss: 6.0439 - val_age_out_loss: 6.5572 - val_age_out_mae: 6.5572 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2516 - val_loss: 6.8088 - learning_rate: 4.1110e-07
# Epoch 76/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8006 - age_out_mae: 5.8006 - gender_out_accuracy: 0.9114 - gender_out_loss: 0.2183 - loss: 6.0189
# Epoch 76: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - age_out_loss: 5.8005 - age_out_mae: 5.8005 - gender_out_accuracy: 0.9114 - gender_out_loss: 0.2183 - loss: 6.0187 - val_age_out_loss: 6.5570 - val_age_out_mae: 6.5570 - val_gender_out_accuracy: 0.9026 - val_gender_out_loss: 0.2516 - val_loss: 6.8086 - learning_rate: 3.6999e-07
# Epoch 77/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8240 - age_out_mae: 5.8240 - gender_out_accuracy: 0.9091 - gender_out_loss: 0.2169 - loss: 6.0409
# Epoch 77: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - age_out_loss: 5.8236 - age_out_mae: 5.8236 - gender_out_accuracy: 0.9091 - gender_out_loss: 0.2169 - loss: 6.0405 - val_age_out_loss: 6.5571 - val_age_out_mae: 6.5571 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8086 - learning_rate: 3.3299e-07
# Epoch 78/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7397 - age_out_mae: 5.7397 - gender_out_accuracy: 0.9074 - gender_out_loss: 0.2203 - loss: 5.9600
# Epoch 78: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 296s 2s/step - age_out_loss: 5.7396 - age_out_mae: 5.7396 - gender_out_accuracy: 0.9074 - gender_out_loss: 0.2203 - loss: 5.9600 - val_age_out_loss: 6.5569 - val_age_out_mae: 6.5569 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8084 - learning_rate: 2.9969e-07
# Epoch 79/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8147 - age_out_mae: 5.8147 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2128 - loss: 6.0275
# Epoch 79: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - age_out_loss: 5.8143 - age_out_mae: 5.8143 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2128 - loss: 6.0271 - val_age_out_loss: 6.5567 - val_age_out_mae: 6.5567 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8082 - learning_rate: 2.6972e-07
# Epoch 80/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7573 - age_out_mae: 5.7573 - gender_out_accuracy: 0.9142 - gender_out_loss: 0.2134 - loss: 5.9707
# Epoch 80: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - age_out_loss: 5.7572 - age_out_mae: 5.7572 - gender_out_accuracy: 0.9142 - gender_out_loss: 0.2134 - loss: 5.9707 - val_age_out_loss: 6.5567 - val_age_out_mae: 6.5567 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8083 - learning_rate: 2.4275e-07
# Epoch 81/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7580 - age_out_mae: 5.7580 - gender_out_accuracy: 0.9104 - gender_out_loss: 0.2199 - loss: 5.9779
# Epoch 81: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 308s 2s/step - age_out_loss: 5.7579 - age_out_mae: 5.7579 - gender_out_accuracy: 0.9104 - gender_out_loss: 0.2199 - loss: 5.9778 - val_age_out_loss: 6.5565 - val_age_out_mae: 6.5565 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8080 - learning_rate: 2.1847e-07
# Epoch 82/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8020 - age_out_mae: 5.8020 - gender_out_accuracy: 0.9131 - gender_out_loss: 0.2134 - loss: 6.0155
# Epoch 82: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - age_out_loss: 5.8018 - age_out_mae: 5.8018 - gender_out_accuracy: 0.9131 - gender_out_loss: 0.2135 - loss: 6.0152 - val_age_out_loss: 6.5566 - val_age_out_mae: 6.5566 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8081 - learning_rate: 1.9663e-07
# Epoch 83/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7467 - age_out_mae: 5.7467 - gender_out_accuracy: 0.9088 - gender_out_loss: 0.2152 - loss: 5.9619
# Epoch 83: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - age_out_loss: 5.7468 - age_out_mae: 5.7468 - gender_out_accuracy: 0.9088 - gender_out_loss: 0.2152 - loss: 5.9620 - val_age_out_loss: 6.5565 - val_age_out_mae: 6.5565 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8079 - learning_rate: 1.7696e-07
# Epoch 84/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7447 - age_out_mae: 5.7447 - gender_out_accuracy: 0.9109 - gender_out_loss: 0.2214 - loss: 5.9661
# Epoch 84: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - age_out_loss: 5.7448 - age_out_mae: 5.7448 - gender_out_accuracy: 0.9109 - gender_out_loss: 0.2214 - loss: 5.9662 - val_age_out_loss: 6.5564 - val_age_out_mae: 6.5564 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8079 - learning_rate: 1.5927e-07
# Epoch 85/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8152 - age_out_mae: 5.8152 - gender_out_accuracy: 0.9093 - gender_out_loss: 0.2197 - loss: 6.0349
# Epoch 85: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 293s 2s/step - age_out_loss: 5.8150 - age_out_mae: 5.8150 - gender_out_accuracy: 0.9093 - gender_out_loss: 0.2197 - loss: 6.0347 - val_age_out_loss: 6.5564 - val_age_out_mae: 6.5564 - val_gender_out_accuracy: 0.9017 - val_gender_out_loss: 0.2515 - val_loss: 6.8079 - learning_rate: 1.4334e-07
# Epoch 86/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - age_out_loss: 5.7622 - age_out_mae: 5.7622 - gender_out_accuracy: 0.9106 - gender_out_loss: 0.2168 - loss: 5.9790
# Epoch 86: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 413s 3s/step - age_out_loss: 5.7622 - age_out_mae: 5.7622 - gender_out_accuracy: 0.9106 - gender_out_loss: 0.2168 - loss: 5.9790 - val_age_out_loss: 6.5563 - val_age_out_mae: 6.5563 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8077 - learning_rate: 1.2901e-07
# Epoch 87/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7135 - age_out_mae: 5.7135 - gender_out_accuracy: 0.9086 - gender_out_loss: 0.2149 - loss: 5.9284
# Epoch 87: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 413s 3s/step - age_out_loss: 5.7138 - age_out_mae: 5.7138 - gender_out_accuracy: 0.9086 - gender_out_loss: 0.2149 - loss: 5.9287 - val_age_out_loss: 6.5562 - val_age_out_mae: 6.5562 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8077 - learning_rate: 1.1611e-07
# Epoch 88/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7222 - age_out_mae: 5.7222 - gender_out_accuracy: 0.9089 - gender_out_loss: 0.2208 - loss: 5.9430
# Epoch 88: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 307s 2s/step - age_out_loss: 5.7226 - age_out_mae: 5.7226 - gender_out_accuracy: 0.9089 - gender_out_loss: 0.2208 - loss: 5.9433 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 1.0450e-07
# Epoch 89/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.8122 - age_out_mae: 5.8122 - gender_out_accuracy: 0.9117 - gender_out_loss: 0.2116 - loss: 6.0238
# Epoch 89: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 302s 2s/step - age_out_loss: 5.8120 - age_out_mae: 5.8120 - gender_out_accuracy: 0.9117 - gender_out_loss: 0.2116 - loss: 6.0236 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 9.4046e-08
# Epoch 90/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7889 - age_out_mae: 5.7889 - gender_out_accuracy: 0.9101 - gender_out_loss: 0.2164 - loss: 6.0053
# Epoch 90: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - age_out_loss: 5.7887 - age_out_mae: 5.7887 - gender_out_accuracy: 0.9101 - gender_out_loss: 0.2164 - loss: 6.0051 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 8.4641e-08
# Epoch 91/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.6578 - age_out_mae: 5.6578 - gender_out_accuracy: 0.9114 - gender_out_loss: 0.2097 - loss: 5.8675
# Epoch 91: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - age_out_loss: 5.6584 - age_out_mae: 5.6584 - gender_out_accuracy: 0.9114 - gender_out_loss: 0.2097 - loss: 5.8681 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 7.6177e-08
# Epoch 92/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7859 - age_out_mae: 5.7859 - gender_out_accuracy: 0.9093 - gender_out_loss: 0.2157 - loss: 6.0017
# Epoch 92: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 372s 2s/step - age_out_loss: 5.7858 - age_out_mae: 5.7858 - gender_out_accuracy: 0.9093 - gender_out_loss: 0.2157 - loss: 6.0016 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 6.8560e-08
# Epoch 93/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7300 - age_out_mae: 5.7300 - gender_out_accuracy: 0.9116 - gender_out_loss: 0.2166 - loss: 5.9466
# Epoch 93: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - age_out_loss: 5.7302 - age_out_mae: 5.7302 - gender_out_accuracy: 0.9116 - gender_out_loss: 0.2166 - loss: 5.9468 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8076 - learning_rate: 6.1704e-08
# Epoch 94/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7238 - age_out_mae: 5.7238 - gender_out_accuracy: 0.9157 - gender_out_loss: 0.2093 - loss: 5.9331
# Epoch 94: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - age_out_loss: 5.7242 - age_out_mae: 5.7242 - gender_out_accuracy: 0.9157 - gender_out_loss: 0.2094 - loss: 5.9335 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 5.5533e-08
# Epoch 95/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7667 - age_out_mae: 5.7667 - gender_out_accuracy: 0.9127 - gender_out_loss: 0.2174 - loss: 5.9840
# Epoch 95: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - age_out_loss: 5.7666 - age_out_mae: 5.7666 - gender_out_accuracy: 0.9127 - gender_out_loss: 0.2174 - loss: 5.9840 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 4.9980e-08
# Epoch 96/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7282 - age_out_mae: 5.7282 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2146 - loss: 5.9428
# Epoch 96: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - age_out_loss: 5.7284 - age_out_mae: 5.7284 - gender_out_accuracy: 0.9097 - gender_out_loss: 0.2146 - loss: 5.9430 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 4.4982e-08
# Epoch 97/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7121 - age_out_mae: 5.7121 - gender_out_accuracy: 0.9070 - gender_out_loss: 0.2229 - loss: 5.9350
# Epoch 97: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 371s 2s/step - age_out_loss: 5.7124 - age_out_mae: 5.7124 - gender_out_accuracy: 0.9070 - gender_out_loss: 0.2229 - loss: 5.9353 - val_age_out_loss: 6.5561 - val_age_out_mae: 6.5561 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 4.0484e-08
# Epoch 98/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.6804 - age_out_mae: 5.6804 - gender_out_accuracy: 0.9125 - gender_out_loss: 0.2136 - loss: 5.8941
# Epoch 98: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 333s 2s/step - age_out_loss: 5.6809 - age_out_mae: 5.6809 - gender_out_accuracy: 0.9125 - gender_out_loss: 0.2136 - loss: 5.8945 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 3.6435e-08
# Epoch 99/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7721 - age_out_mae: 5.7721 - gender_out_accuracy: 0.9101 - gender_out_loss: 0.2207 - loss: 5.9928
# Epoch 99: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 402s 2s/step - age_out_loss: 5.7721 - age_out_mae: 5.7721 - gender_out_accuracy: 0.9101 - gender_out_loss: 0.2207 - loss: 5.9928 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 3.2792e-08
# Epoch 100/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 5.7658 - age_out_mae: 5.7658 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2134 - loss: 5.9791
# Epoch 100: val_gender_out_accuracy did not improve from 0.90299
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - age_out_loss: 5.7657 - age_out_mae: 5.7657 - gender_out_accuracy: 0.9113 - gender_out_loss: 0.2134 - loss: 5.9791 - val_age_out_loss: 6.5560 - val_age_out_mae: 6.5560 - val_gender_out_accuracy: 0.9022 - val_gender_out_loss: 0.2515 - val_loss: 6.8075 - learning_rate: 2.9513e-08

# %%
acc = history.history['gender_out_accuracy']
val_acc = history.history['val_gender_out_accuracy']
epochs = range(len(acc))

# %%
plt.plot(epochs, acc, 'b', label='Training Loss')
plt.plot(epochs, val_acc, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
plt.plot(history.history['gender_out_accuracy'])
plt.plot(history.history['val_gender_out_accuracy'])
plt.title('Gender loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['age_out_mae'])
plt.plot(history.history['val_age_out_mae'])
plt.title('Age loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
image_index = 3000
print(f"Original Gender: \t{gender_dict[y_gender[image_index]]} \t Original Age: \t{y_age[image_index]}")

pred = model.predict(X[image_index].reshape(1,128,128,1))
pred_gender = gender_dict[int(round(pred[0][0][0]))]  
pred_age = round(pred[1][0][0])
print(f"Predicted Gender: \t{pred_gender}\t Predicted Age \t{pred_age}")
plt.title(f'Gender: {pred_gender}, Age: {pred_age}')
plt.imshow(X[image_index].reshape(128,128), cmap='gray') 
plt.show()

# %%
image_index = 50
print(f"Original Gender: \t{gender_dict[y_gender[image_index]]} \t Original Age: \t{y_age[image_index]}")

pred = model.predict(X[image_index].reshape(1,128,128,1))
pred_gender = gender_dict[int(round(pred[0][0][0]))]  
pred_age = round(pred[1][0][0])
print(f"Predicted Gender: \t{pred_gender}\t Predicted Age \t{pred_age}")
plt.title(f'Gender: {pred_gender}, Age: {pred_age}')
plt.imshow(X[image_index].reshape(128,128), cmap='gray') 
plt.show()
# Out:
# Original Gender: 	Male 	 Original Age: 	10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Predicted Gender: 	Male	 Predicted Age 	9

# %%
image_index = 35
print(f"Original Gender: \t{gender_dict[y_gender[image_index]]} \t Original Age: \t{y_age[image_index]}")

pred = model.predict(X[image_index].reshape(1,128,128,1))
pred_gender = gender_dict[int(round(pred[0][0][0]))]  
pred_age = round(pred[1][0][0])
print(f"Predicted Gender: \t{pred_gender}\t Predicted Age \t{pred_age}")
plt.title(f'Gender: {pred_gender}, Age: {pred_age}')
plt.imshow(X[image_index].reshape(128,128), cmap='gray') 
plt.show()

# %%
model.save("age_gender_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = load_model("age_gender_model.h5", custom_objects={'mae': 'mae'})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
